# %% [markdown]
# 1.Sebuah wahana bermain 'Disney Island' akan memberikan tarif sesuai dengan tinggi dan umur anak dengan ketentuan sebagai berikut:
#
# -Umur kurang dari 2 tahun: Tampilkan 'Dilarang masuk'
#
# -Umur kurang dari 4 tahun: Rp 30.000. Jika tinggi anak umur 2-3 tahun melebihi 70 cm maka tarif akan bertambah 10.000
#
# -Umur kurang dari 7 tahun: Rp 40.000. Jika tinggi anak umur 4-6 tahun melebih 120 cm maka tarif akan bertambah 15.000
#
# -Umur kurang dari 10 tahun: Rp 50.000. Jika tinggi anak umur 8-9 tahun melebih 150 cm maka tarif akan bertambah 20.000
#
# -Umur 10 tahun keatas: Rp 80.000
#
# Buatlah program untuk menampilkan tarif harga sesuai umur dan tinggi seorang anak!

# %%
usia = int(input('Masukkan usia: '))
tinggi = int(input('Masukkan tinggi: '))

if usia < 2:
    print('Dilarang Masuk')
elif usia < 4:
    if (tinggi <= 70):
        print('Untuk usia',usia,'tahun dengan tinggi',tinggi,'Cm harga tiket nya yaitu Rp. 30.000')
    else:
        print('Untuk usia',usia,'tahun dengan tinggi',tinggi,'Cm harga tiket nya yaitu Rp.',30000 + 10000)
elif usia < 7:
    if (tinggi <= 120):
        print('Untuk usia',usia,'tahun dengan tinggi',tinggi,'Cm harga tiket nya yaitu Rp. 40.000')
    else:
        print('Untuk usia',usia,'tahun dengan tinggi',tinggi,'Cm harga tiket nya yaitu Rp.',40000 + 15000)
elif usia < 10:
    if (tinggi <= 150):
        print('Untuk usia',usia,'tahun dengan tinggi',tinggi,'Cm harga tiket nya yaitu Rp. 50.000')
    else:
        print('Untuk usia',usia,'tahun dengan tinggi',tinggi,'Cm harga tiket nya yaitu Rp.',50000 + 20000)
else:
        print('Untuk usia',usia,'tahun dengan tinggi',tinggi,'Cm harga tiket nya yaitu Rp. 80.000')
# Out:
# Masukkan usia: 9
# Masukkan tinggi: 150
# Untuk usia 9 tahun dengan tinggi 150 Cm harga tiket nya yaitu Rp. 50.000

# %% [markdown]
# 2.Terdapat sebuah jurnal yang menuliskan teorinya bahwa olahraga dapat membakar kalori yang terkandung dalam tubuh manusia. Hal tersebut berbanding lurus dengan lama waktu yang dilakukan. Berikut ini adalah beberapa teori tersebut:
#
# -Olahraga lari membakar 60 kalori setiap 5 menit.
#
# -Olahraga push-up membakar 200 kalori setiap 30 menit
#
# -Olahraga plank membakar 5 kalori selama 1 menit
#
# Buatlah program berdasarkan uraian tersebut untuk menghitung berapa jumlah kalori yang terbakar setelah melakukan aktivitas olahraga tersebut dengan ketentuan setiap orang boleh melakukan aktivitasnya lebih dari 1 (satu).

# %%
kalori = 0
lari = input("Apakah kamu melakukan lari? ")
pushUp = input("Apakah kamu melakukan push-up? ")
plank = input("Apakah kamu melakukan plank? ")

if (lari == "ya"):
    menit = int(input("Berapa menit melakukan lari? "))
    kalori += menit * (60 / 5)
if (pushUp == "ya"):
    menit = int(input("Berapa menit melakukan push-up ? "))
    kalori += menit * (200 / 30)  
if (plank == "ya"):
    menit = int(input("Berapa menit melakukan plank ? "))
    kalori += menit * 5
    
kalori = int(kalori)

if (kalori > 0):
    print('\nKalori yang terbakar adalah',kalori,'kalori')
else:
    print("\nTidak ada kalori yang terbakar")
# Out:
# Apakah kamu melakukan lari? ya
# Apakah kamu melakukan push-up? ya
# Apakah kamu melakukan plank? tidak
# Berapa menit melakukan lari? 12
# Berapa menit melakukan push-up ? 14
#
# Kalori yang terbakar adalah 237 kalori
