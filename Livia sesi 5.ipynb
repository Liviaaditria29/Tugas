# %%
nama = input("Masukan Nama Anda : ")
kelas = input("Masukan Nama Kelas Anda : ")
alamat = input("Masukan Alamat Anda : ")
hobi = input("Masukan Hobi Anda : ")
print("\nNama saya {}, saya dari kelas {}, alamat di {}, hobi saya adalah {}, sekian terima kasih".format(nama, kelas, alamat, hobi))
# Out:
# Masukan Nama Anda : Livia Aditria
# Masukan Nama Kelas Anda : TI22H
# Masukan Alamat Anda : Lio Asem
# Masukan Hobi Anda : Bermain Gitar
#
# Nama saya Livia Aditria, saya dari kelas TI22H, alamat di Lio Asem, hobi saya adalah Bermain Gitar, sekian terima kasih

# %%
kalimat = ("UNIVERSITAS NUSA PUTRA SUKABUMI")
print(kalimat.lower()[17:22], kalimat.lower()[12:16])
print(kalimat.replace('U', ''))
print(kalimat[23:31],kalimat[17:22],kalimat[12:16],kalimat[0:11])
print(kalimat[0]+kalimat[12]+kalimat[17]+kalimat[23])
print(kalimat[8:11],kalimat[14:16]+kalimat[17:19],kalimat[27:31])
# Out:
# putra nusa
# NIVERSITAS NSA PTRA SKABMI
# SUKABUMI PUTRA NUSA UNIVERSITAS
# UNPS
# TAS SAPU BUMI
